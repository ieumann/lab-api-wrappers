# %% [markdown]
# #### Instructions
#
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster.
# The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import math

# %%
#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="af3a4e21d9974f798b0ddef081728f2b",
                                                           client_secret="99a65d20eff04d64bcf24b11824dffc4"))

# %% [markdown]
# #### I am using one of my own playlists since I consider it highly curated ;) and it is rather diverse in audio features.

# %%
playlist = sp.user_playlist_tracks("spotify", "4PuzKqMQjuIvn3Arkgaek2")
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4PuzKqMQjuIvn3Arkgaek2/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2017-06-19T12:35:19Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5jmpVuzUhQufrVLxKFwvU1'},
#        'href': 'https://api.spotify.com/v1/artists/5jmpVuzUhQufrVLxKFwvU1',
#        'id': '5jmpVuzUhQufrVLxKFwvU1',
#        'name': 'Bitori',
#        'type': 'artist',
#        'uri': 'spotify:artist:5jmpVuzUhQufrVLxKFwvU1'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3e9bOeAVDHnVHPqHjMGKFB'},
#      'href': 'https://api.spotify.com/v1/albums/3e9bOeAVDHnVHPqHjMGKFB',
#      'id': '3e9bOeAVDHnVHPqHjMGKFB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a46937c5e779c2eafdc7b9e9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a46937c5e779c2eafdc7b9e9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a46937c5e779c2eafdc7b9e9',
#        'width': 64}],
#      'name': 'Bitori: Legend of Funaná, the Forbidden Music of the Cape Verde Island (Analog Africa No. 21)',
#      'release_date': '2016-09-02',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:3e9bOeAVDHnVHPqHjMGKFB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5jmpVuzUhQufrVLxKFwvU1'},
#       'href': 'https://api.spotify.com/v1/artists/5jmpVuzUhQufrVLxKFwvU1',
#       'id': '5jmpVuzUhQufrVLxKFwvU1',
#       'name': 'Bitori',
#       'type': 'artist',
#       'uri': 'spotify:artist:5jmpVuzUhQufrVLxKFwvU1'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 258776,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DENR91681005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2r3OCxXToV0DoXi0Cwf5LZ'},
#     'href': 'https://api.spotify.com/v1/tracks/2r3OCxXToV0DoXi0Cwf5LZ',
#     'id': '2r3OCxXToV0DoXi0Cwf5LZ',
#     'is_local': False,
#     'name': 'Munana',
#     'popularity': 9,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c34b69749fce763e86784b1a9bfd14063d6a4315?cid=af3a4e21d9974f798b0ddef081728f2b',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:2r3OCxXToV0DoXi0Cwf5LZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-06-19T12:34:30Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xT0arvCDupDU1YYy0BNv9'},
#        'href': 'https://api.spotify.com/v1/artists/7xT0arvCDupDU1YYy0BNv9',
#        'id': '7xT0arvCDupDU1YYy0BNv9',
#        'name': 'Orchestra Baobab',
#        'type': 'artist',
#        'uri': 'spotify:artist:7xT0arvCDupDU1YYy0BNv9'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4QuxaZxodr5DurYJyb2EbC'},
#      'href': 'https://api.spotify.com/v1/albums/4QuxaZxodr5DurYJyb2EbC',
#      'id': '4QuxaZxodr5DurYJyb2EbC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273567046f0e266d669ed073a58',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02567046f0e266d669ed073a58',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851567046f0e266d669ed073a58',
#        'width': 64}],
#      'name': 'Tribute to Ndiouga Dieng',
#      'release_date': '2017-03-31',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4QuxaZxodr5DurYJyb2EbC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7xT0arvCDupDU1YYy0BNv9'},
#       'href': 'https://api.spotify.com/v1/artists/7xT0arvCDupDU1YYy0BNv9',
#       'id': '7xT0arvCDupDU1YYy0BNv9',
#       'name': 'Orchestra Baobab',
#       'type': 'artist',
#       'uri': 'spotify:artist:7xT0arvCDupDU1YYy0BNv9'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 274840,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBGU1692007'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MmuoqMXkyUvzkUtR6pH5N'},
#     'href': 'https://api.spotify.com/v1/tracks/7MmuoqMXkyUvzkUtR6pH5N',
#     'id': '7MmuoqMXkyUvzkUtR6pH5N',
#     'is_local': False,
#     'name': 'Sey',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7MmuoqMXkyUvzkUtR6pH5N'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-11T15:22:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5abSRg0xN1NV3gLbuvX24M'},
#        'href': 'https://api.spotify.com/v1/artists/5abSRg0xN1NV3gLbuvX24M',
#        'id': '5abSRg0xN1NV3gLbuvX24M',
#        'name': 'Amr Diab',
#        'type': 'artist',
#        'uri': 'spotify:artist:5abSRg0xN1NV3gLbuvX24M'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0cI57WZJUqA8rV21t8Zhzn'},
#      'href': 'https://api.spotify.com/v1/albums/0cI57WZJUqA8rV21t8Zhzn',
#      'id': '0cI57WZJUqA8rV21t8Zhzn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b4d583b6ec497460a1070a09',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b4d583b6ec497460a1070a09',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b4d583b6ec497460a1070a09',
#        'width': 64}],
#      'name': 'Amr Diab: Greatest Hits 2013',
#      'release_date': '2011',
#      'release_date_precision': 'year',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:0cI57WZJUqA8rV21t8Zhzn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5abSRg0xN1NV3gLbuvX24M'},
#       'href': 'https://api.spotify.com/v1/artists/5abSRg0xN1NV3gLbuvX24M',
#       'id': '5abSRg0xN1NV3gLbuvX24M',
#       'name': 'Amr Diab',
#       'type': 'artist',
#       'uri': 'spotify:artist:5abSRg0xN1NV3gLbuvX24M'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 264254,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA370644606'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ZLz817NgIAr4IxZxvd9hU'},
#     'href': 'https://api.spotify.com/v1/tracks/3ZLz817NgIAr4IxZxvd9hU',
#     'id': '3ZLz817NgIAr4IxZxvd9hU',
#     'is_local': False,
#     'name': 'Qusad Einy',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 18,
#     'type': 'track',
#     'uri': 'spotify:track:3ZLz817NgIAr4IxZxvd9hU'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-06-19T12:35:11Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MvRVq0CtpQQlwnIiszV8F'},
#        'href': 'https://api.spotify.com/v1/artists/6MvRVq0CtpQQlwnIiszV8F',
#        'id': '6MvRVq0CtpQQlwnIiszV8F',
#        'name': 'Magic System',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MvRVq0CtpQQlwnIiszV8F'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5RMK3fHvBHJe4GcK3HU557'},
#      'href': 'https://api.spotify.com/v1/albums/5RMK3fHvBHJe4GcK3HU557',
#      'id': '5RMK3fHvBHJe4GcK3HU557',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b92abbe98372f1e532b2cd3d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b92abbe98372f1e532b2cd3d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b92abbe98372f1e532b2cd3d',
#        'width': 64}],
#      'name': '1er Gaou',
#      'release_date': '2006',
#      'release_date_precision': 'year',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5RMK3fHvBHJe4GcK3HU557'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MvRVq0CtpQQlwnIiszV8F'},
#       'href': 'https://api.spotify.com/v1/artists/6MvRVq0CtpQQlwnIiszV8F',
#       'id': '6MvRVq0CtpQQlwnIiszV8F',
#       'name': 'Magic System',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MvRVq0CtpQQlwnIiszV8F'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 294200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRZ110601255'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0LpNLPdGvZLATY6JgdbQzk'},
#     'href': 'https://api.spotify.com/v1/tracks/0LpNLPdGvZLATY6JgdbQzk',
#     'id': '0LpNLPdGvZLATY6JgdbQzk',
#     'is_local': False,
#     'name': '1er Gaou',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0LpNLPdGvZLATY6JgdbQzk'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-11T15:24:57Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yXp8e4tFfb3wAjMnBOAlp'},
#        'href': 'https://api.spotify.com/v1/artists/4yXp8e4tFfb3wAjMnBOAlp',
#        'id': '4yXp8e4tFfb3wAjMnBOAlp',
#        'name': 'Jul De Grenelle',
#        'type': 'artist',
#        'uri': 'spotify:artist:4yXp8e4tFfb3wAjMnBOAlp'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7e6nFXVjaltQGfuaUsAAiD'},
#      'href': 'https://api.spotify.com/v1/albums/7e6nFXVjaltQGfuaUsAAiD',
#      'id': '7e6nFXVjaltQGfuaUsAAiD',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e0d1fdfda3f1605771a32897',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e0d1fdfda3f1605771a32897',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e0d1fdfda3f1605771a32897',
#        'width': 64}],
#      'name': 'Danai',
#      'release_date': '2010-06-01',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7e6nFXVjaltQGfuaUsAAiD'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4yXp8e4tFfb3wAjMnBOAlp'},
#       'href': 'https://api.spotify.com/v1/artists/4yXp8e4tFfb3wAjMnBOAlp',
#       'id': '4yXp8e4tFfb3wAjMnBOAlp',
#       'name': 'Jul De Grenelle',
#       'type': 'artist',
#       'uri': 'spotify:artist:4yXp8e4tFfb3wAjMnBOAlp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1eqWWXUZm6BpkpJ2gJcrvb'},
#       'href': 'https://api.spotify.com/v1/artists/1eqWWXUZm6BpkpJ2gJcrvb',
#       'id': '1eqWWXUZm6BpkpJ2gJcrvb',
#       'name': 'Benoit Cassar',
#       'type': 'artist',
#       'uri': 'spotify:artist:1eqWWXUZm6BpkpJ2gJcrvb'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3DHa3ApZYHmk8Pb3JgWsDT'},
#       'href': 'https://api.spotify.com/v1/artists/3DHa3ApZYHmk8Pb3JgWsDT',
#       'id': '3DHa3ApZYHmk8Pb3JgWsDT',
#       'name': 'Guitara',
#       'type': 'artist',
#       'uri': 'spotify:artist:3DHa3ApZYHmk8Pb3JgWsDT'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 223304,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR6V80843032'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3UhMrPQkV70OWjhRPZnqi9'},
#     'href': 'https://api.spotify.com/v1/tracks/3UhMrPQkV70OWjhRPZnqi9',
#     'id': '3UhMrPQkV70OWjhRPZnqi9',
#     'is_local': False,
#     'name': 'Ya Ghaly - Danai Remix',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:3UhMrPQkV70OWjhRPZnqi9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-11T15:29:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uOgBVYHvqTGAQ5iVHDVT7'},
#        'href': 'https://api.spotify.com/v1/artists/6uOgBVYHvqTGAQ5iVHDVT7',
#        'id': '6uOgBVYHvqTGAQ5iVHDVT7',
#        'name': 'Ragheb Alama',
#        'type': 'artist',
#        'uri': 'spotify:artist:6uOgBVYHvqTGAQ5iVHDVT7'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1dj55G9LZC4mbe8KaFFmHa'},
#      'href': 'https://api.spotify.com/v1/albums/1dj55G9LZC4mbe8KaFFmHa',
#      'id': '1dj55G9LZC4mbe8KaFFmHa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273be6b3e1190093793d9b0af74',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02be6b3e1190093793d9b0af74',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851be6b3e1190093793d9b0af74',
#        'width': 64}],
#      'name': 'El Hob El Kebir',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1dj55G9LZC4mbe8KaFFmHa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6uOgBVYHvqTGAQ5iVHDVT7'},
#       'href': 'https://api.spotify.com/v1/artists/6uOgBVYHvqTGAQ5iVHDVT7',
#       'id': '6uOgBVYHvqTGAQ5iVHDVT7',
#       'name': 'Ragheb Alama',
#       'type': 'artist',
#       'uri': 'spotify:artist:6uOgBVYHvqTGAQ5iVHDVT7'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 270200,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'EGA020501929'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1qQqHzG5JAYD2bV1DGf5v7'},
#     'href': 'https://api.spotify.com/v1/tracks/1qQqHzG5JAYD2bV1DGf5v7',
#     'id': '1qQqHzG5JAYD2bV1DGf5v7',
#     'is_local': False,
#     'name': 'Nasini El Donya',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8e99b208c07e24a4d01a68fb9e70575239c476c2?cid=af3a4e21d9974f798b0ddef081728f2b',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1qQqHzG5JAYD2bV1DGf5v7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-11T15:32:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68rvMwPL0yMbYR5cv0pzCR'},
#        'href': 'https://api.spotify.com/v1/artists/68rvMwPL0yMbYR5cv0pzCR',
#        'id': '68rvMwPL0yMbYR5cv0pzCR',
#        'name': 'Elissa',
#        'type': 'artist',
#        'uri': 'spotify:artist:68rvMwPL0yMbYR5cv0pzCR'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/72W0atlnwcgphZjve5XAap'},
#      'href': 'https://api.spotify.com/v1/albums/72W0atlnwcgphZjve5XAap',
#      'id': '72W0atlnwcgphZjve5XAap',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734dcdd97c1549d8c88f1859d4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024dcdd97c1549d8c88f1859d4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514dcdd97c1549d8c88f1859d4',
#        'width': 64}],
#      'name': 'سهرنا يا ليل',
#      'release_date': '2016-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:72W0atlnwcgphZjve5XAap'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68rvMwPL0yMbYR5cv0pzCR'},
#       'href': 'https://api.spotify.com/v1/artists/68rvMwPL0yMbYR5cv0pzCR',
#       'id': '68rvMwPL0yMbYR5cv0pzCR',
#       'name': 'Elissa',
#       'type': 'artist',
#       'uri': 'spotify:artist:68rvMwPL0yMbYR5cv0pzCR'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 300440,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'LBA081122402'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3E2cxGYBulFh1JA4hkdont'},
#     'href': 'https://api.spotify.com/v1/tracks/3E2cxGYBulFh1JA4hkdont',
#     'id': '3E2cxGYBulFh1JA4hkdont',
#     'is_local': False,
#     'name': 'قلب و روح',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:3E2cxGYBulFh1JA4hkdont'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-11T15:33:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/35RDQEuRFD2Zit0dFZJPre'},
#        'href': 'https://api.spotify.com/v1/artists/35RDQEuRFD2Zit0dFZJPre',
#        'id': '35RDQEuRFD2Zit0dFZJPre',
#        'name': 'Mahlaki',
#        'type': 'artist',
#        'uri': 'spotify:artist:35RDQEuRFD2Zit0dFZJPre'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5qdx4aXMy19SfiYiYpvMCo'},
#      'href': 'https://api.spotify.com/v1/albums/5qdx4aXMy19SfiYiYpvMCo',
#      'id': '5qdx4aXMy19SfiYiYpvMCo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a7b20ea0aa03cfdf062115f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a7b20ea0aa03cfdf062115f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a7b20ea0aa03cfdf062115f',
#        'width': 64}],
#      'name': 'Arabic Songs',
#      'release_date': '2016-07-03',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:5qdx4aXMy19SfiYiYpvMCo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/46FJPTBdnCK0GMd76nil6e'},
#       'href': 'https://api.spotify.com/v1/artists/46FJPTBdnCK0GMd76nil6e',
#       'id': '46FJPTBdnCK0GMd76nil6e',
#       'name': 'Yara',
#       'type': 'artist',
#       'uri': 'spotify:artist:46FJPTBdnCK0GMd76nil6e'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 219560,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBLFP1604241'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Xg94xsCFHtogZEin4ZoIk'},
#     'href': 'https://api.spotify.com/v1/tracks/6Xg94xsCFHtogZEin4ZoIk',
#     'id': '6Xg94xsCFHtogZEin4ZoIk',
#     'is_local': False,
#     'name': 'Beyt Habibi',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:6Xg94xsCFHtogZEin4ZoIk'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-11T15:33:28Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/35RDQEuRFD2Zit0dFZJPre'},
#        'href': 'https://api.spotify.com/v1/artists/35RDQEuRFD2Zit0dFZJPre',
#        'id': '35RDQEuRFD2Zit0dFZJPre',
#        'name': 'Mahlaki',
#        'type': 'artist',
#        'uri': 'spotify:artist:35RDQEuRFD2Zit0dFZJPre'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5qdx4aXMy19SfiYiYpvMCo'},
#      'href': 'https://api.spotify.com/v1/albums/5qdx4aXMy19SfiYiYpvMCo',
#      'id': '5qdx4aXMy19SfiYiYpvMCo',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a7b20ea0aa03cfdf062115f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a7b20ea0aa03cfdf062115f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a7b20ea0aa03cfdf062115f',
#        'width': 64}],
#      'name': 'Arabic Songs',
#      'release_date': '2016-07-03',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:5qdx4aXMy19SfiYiYpvMCo'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/09A6IffSw0t8L8sfuOCVws'},
#       'href': 'https://api.spotify.com/v1/artists/09A6IffSw0t8L8sfuOCVws',
#       'id': '09A6IffSw0t8L8sfuOCVws',
#       'name': 'Wael Kfoury',
#       'type': 'artist',
#       'uri': 'spotify:artist:09A6IffSw0t8L8sfuOCVws'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 298110,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBLFP1604233'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0d6nZBImQyT3ypZQbyBPvu'},
#     'href': 'https://api.spotify.com/v1/tracks/0d6nZBImQyT3ypZQbyBPvu',
#     'id': '0d6nZBImQyT3ypZQbyBPvu',
#     'is_local': False,
#     'name': 'Al Gharam El Moustahil',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0d6nZBImQyT3ypZQbyBPvu'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-15T11:12:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0aVJmlOwIxTZeHzhFiFL5Y'},
#        'href': 'https://api.spotify.com/v1/artists/0aVJmlOwIxTZeHzhFiFL5Y',
#        'id': '0aVJmlOwIxTZeHzhFiFL5Y',
#        'name': 'Natacha Atlas',
#        'type': 'artist',
#        'uri': 'spotify:artist:0aVJmlOwIxTZeHzhFiFL5Y'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0DuyAdUsxO22IPSO9CYTV8'},
#      'href': 'https://api.spotify.com/v1/albums/0DuyAdUsxO22IPSO9CYTV8',
#      'id': '0DuyAdUsxO22IPSO9CYTV8',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d90e01dc097a20225c0474de',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d90e01dc097a20225c0474de',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d90e01dc097a20225c0474de',
#        'width': 64}],
#      'name': 'Best Of',
#      'release_date': '2005-05-23',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:0DuyAdUsxO22IPSO9CYTV8'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0aVJmlOwIxTZeHzhFiFL5Y'},
#       'href': 'https://api.spotify.com/v1/artists/0aVJmlOwIxTZeHzhFiFL5Y',
#       'id': '0aVJmlOwIxTZeHzhFiFL5Y',
#       'name': 'Natacha Atlas',
#       'type': 'artist',
#       'uri': 'spotify:artist:0aVJmlOwIxTZeHzhFiFL5Y'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 160160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBBKU9700202'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/12jBokt4TPkm3H3F6k8HSn'},
#     'href': 'https://api.spotify.com/v1/tracks/12jBokt4TPkm3H3F6k8HSn',
#     'id': '12jBokt4TPkm3H3F6k8HSn',
#     'is_local': False,
#     'name': 'Amulet - 2005 Edit',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:12jBokt4TPkm3H3F6k8HSn'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-31T08:28:22Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yq7sI87s5V3Z461Npd652'},
#        'href': 'https://api.spotify.com/v1/artists/0yq7sI87s5V3Z461Npd652',
#        'id': '0yq7sI87s5V3Z461Npd652',
#        'name': 'Ahmed Fakroun',
#        'type': 'artist',
#        'uri': 'spotify:artist:0yq7sI87s5V3Z461Npd652'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3817vwUTrue6AUYFywpZU5'},
#      'href': 'https://api.spotify.com/v1/albums/3817vwUTrue6AUYFywpZU5',
#      'id': '3817vwUTrue6AUYFywpZU5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27327554eb09e53876aea45e23d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0227554eb09e53876aea45e23d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485127554eb09e53876aea45e23d',
#        'width': 64}],
#      'name': 'Compilation',
#      'release_date': '2010-10-07',
#      'release_date_precision': 'day',
#      'total_tracks': 34,
#      'type': 'album',
#      'uri': 'spotify:album:3817vwUTrue6AUYFywpZU5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0yq7sI87s5V3Z461Npd652'},
#       'href': 'https://api.spotify.com/v1/artists/0yq7sI87s5V3Z461Npd652',
#       'id': '0yq7sI87s5V3Z461Npd652',
#       'name': 'Ahmed Fakroun',
#       'type': 'artist',
#       'uri': 'spotify:artist:0yq7sI87s5V3Z461Npd652'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 257019,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'ushm91060873'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/67OOgbV2tnbkMjWSgIrWMx'},
#     'href': 'https://api.spotify.com/v1/tracks/67OOgbV2tnbkMjWSgIrWMx',
#     'id': '67OOgbV2tnbkMjWSgIrWMx',
#     'is_local': False,
#     'name': 'Nisyan',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e5f7e240818f91bebbfaa7915dba6682c4380039?cid=af3a4e21d9974f798b0ddef081728f2b',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:67OOgbV2tnbkMjWSgIrWMx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-05-31T08:58:58Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1TlzWlyjSPJqgGi3nAnU8i'},
#      'href': 'https://api.spotify.com/v1/albums/1TlzWlyjSPJqgGi3nAnU8i',
#      'id': '1TlzWlyjSPJqgGi3nAnU8i',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27336f72bf367f0f5de3a88648d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0236f72bf367f0f5de3a88648d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485136f72bf367f0f5de3a88648d',
#        'width': 64}],
#      'name': 'Nova le grand mix 2016',
#      'release_date': '2016-12-09',
#      'release_date_precision': 'day',
#      'total_tracks': 91,
#      'type': 'album',
#      'uri': 'spotify:album:1TlzWlyjSPJqgGi3nAnU8i'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7s4I6rDvTcdBDKElVbtsAN'},
#       'href': 'https://api.spotify.com/v1/artists/7s4I6rDvTcdBDKElVbtsAN',
#       'id': '7s4I6rDvTcdBDKElVbtsAN',
#       'name': 'Bombino',
#       'type': 'artist',
#       'uri': 'spotify:artist:7s4I6rDvTcdBDKElVbtsAN'}],
#     'available_markets': [],
#     'disc_number': 2,
#     'duration_ms': 291013,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBQU1500717'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6fOCGlTiIPzx5YP2vYQMnZ'},
#     'href': 'https://api.spotify.com/v1/tracks/6fOCGlTiIPzx5YP2vYQMnZ',
#     'id': '6fOCGlTiIPzx5YP2vYQMnZ',
#     'is_local': False,
#     'name': 'Timtar',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:6fOCGlTiIPzx5YP2vYQMnZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-06-01T07:48:06Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7t3VJCyz87PJLqHM3mOt3I'},
#        'href': 'https://api.spotify.com/v1/artists/7t3VJCyz87PJLqHM3mOt3I',
#        'id': '7t3VJCyz87PJLqHM3mOt3I',
#        'name': 'Al Massrieen',
#        'type': 'artist',
#        'uri': 'spotify:artist:7t3VJCyz87PJLqHM3mOt3I'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4etdTKHbGjNPF4AmMMaj6j'},
#      'href': 'https://api.spotify.com/v1/albums/4etdTKHbGjNPF4AmMMaj6j',
#      'id': '4etdTKHbGjNPF4AmMMaj6j',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737525524145c82faa15afdd72',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027525524145c82faa15afdd72',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517525524145c82faa15afdd72',
#        'width': 64}],
#      'name': 'Modern Music (Habibi Funk 006)',
#      'release_date': '2017-04-28',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4etdTKHbGjNPF4AmMMaj6j'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7t3VJCyz87PJLqHM3mOt3I'},
#       'href': 'https://api.spotify.com/v1/artists/7t3VJCyz87PJLqHM3mOt3I',
#       'id': '7t3VJCyz87PJLqHM3mOt3I',
#       'name': 'Al Massrieen',
#       'type': 'artist',
#       'uri': 'spotify:artist:7t3VJCyz87PJLqHM3mOt3I'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 224000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DESY21400556'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5ak2hgkL7iZKMxm7jGUHwC'},
#     'href': 'https://api.spotify.com/v1/tracks/5ak2hgkL7iZKMxm7jGUHwC',
#     'id': '5ak2hgkL7iZKMxm7jGUHwC',
#     'is_local': False,
#     'name': 'Sah',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5ak2hgkL7iZKMxm7jGUHwC'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-02-11T15:27:43Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68rvMwPL0yMbYR5cv0pzCR'},
#        'href': 'https://api.spotify.com/v1/artists/68rvMwPL0yMbYR5cv0pzCR',
#        'id': '68rvMwPL0yMbYR5cv0pzCR',
#        'name': 'Elissa',
#        'type': 'artist',
#        'uri': 'spotify:artist:68rvMwPL0yMbYR5cv0pzCR'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6lxsclXgPMRPBKd17sykBx'},
#      'href': 'https://api.spotify.com/v1/albums/6lxsclXgPMRPBKd17sykBx',
#      'id': '6lxsclXgPMRPBKd17sykBx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273368157e83d5ebc47319dec9d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02368157e83d5ebc47319dec9d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851368157e83d5ebc47319dec9d',
#        'width': 64}],
#      'name': 'Halet Hob',
#      'release_date': '2014-07-25',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:6lxsclXgPMRPBKd17sykBx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68rvMwPL0yMbYR5cv0pzCR'},
#       'href': 'https://api.spotify.com/v1/artists/68rvMwPL0yMbYR5cv0pzCR',
#       'id': '68rvMwPL0yMbYR5cv0pzCR',
#       'name': 'Elissa',
#       'type': 'artist',
#       'uri': 'spotify:artist:68rvMwPL0yMbYR5cv0pzCR'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 309028,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'QMFMG1496701'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5xlu3xpamok0JTgjMs5X1h'},
#     'href': 'https://api.spotify.com/v1/tracks/5xlu3xpamok0JTgjMs5X1h',
#     'id': '5xlu3xpamok0JTgjMs5X1h',
#     'is_local': False,
#     'name': 'Halet Hob',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5xlu3xpamok0JTgjMs5X1h'},
#    'video_thumbnail': {'url': None}},
# ...
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 237480,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF011900195'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4h3wVKjCwSefpn9XTDBgRV'},
#     'href': 'https://api.spotify.com/v1/tracks/4h3wVKjCwSefpn9XTDBgRV',
#     'id': '4h3wVKjCwSefpn9XTDBgRV',
#     'is_local': False,
#     'name': 'Tiembla',
#     'popularity': 20,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a1137dd69dd73a67b9de60961fe6cc7295c3e044?cid=af3a4e21d9974f798b0ddef081728f2b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4h3wVKjCwSefpn9XTDBgRV'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-05-21T15:22:18Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68rvMwPL0yMbYR5cv0pzCR'},
#        'href': 'https://api.spotify.com/v1/artists/68rvMwPL0yMbYR5cv0pzCR',
#        'id': '68rvMwPL0yMbYR5cv0pzCR',
#        'name': 'Elissa',
#        'type': 'artist',
#        'uri': 'spotify:artist:68rvMwPL0yMbYR5cv0pzCR'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3G7R4XOGkMIitcWfsSH0md'},
#      'href': 'https://api.spotify.com/v1/albums/3G7R4XOGkMIitcWfsSH0md',
#      'id': '3G7R4XOGkMIitcWfsSH0md',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273056ff011bde40d06436f0fe5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02056ff011bde40d06436f0fe5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851056ff011bde40d06436f0fe5',
#        'width': 64}],
#      'name': 'Elissa',
#      'release_date': '2020-04-27',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3G7R4XOGkMIitcWfsSH0md'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/68rvMwPL0yMbYR5cv0pzCR'},
#       'href': 'https://api.spotify.com/v1/artists/68rvMwPL0yMbYR5cv0pzCR',
#       'id': '68rvMwPL0yMbYR5cv0pzCR',
#       'name': 'Elissa',
#       'type': 'artist',
#       'uri': 'spotify:artist:68rvMwPL0yMbYR5cv0pzCR'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 587023,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBLFP2056283'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6JYcFSZnlDWvbHvUcwP2XL'},
#     'href': 'https://api.spotify.com/v1/tracks/6JYcFSZnlDWvbHvUcwP2XL',
#     'id': '6JYcFSZnlDWvbHvUcwP2XL',
#     'is_local': False,
#     'name': 'Halet Hob & Ertah W Eish',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:6JYcFSZnlDWvbHvUcwP2XL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-03T21:01:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27JrHY7vnpdv1zEfe3F8FQ'},
#        'href': 'https://api.spotify.com/v1/artists/27JrHY7vnpdv1zEfe3F8FQ',
#        'id': '27JrHY7vnpdv1zEfe3F8FQ',
#        'name': 'Beken',
#        'type': 'artist',
#        'uri': 'spotify:artist:27JrHY7vnpdv1zEfe3F8FQ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CD',
#       'CG',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'ET',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IQ',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'LY',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TJ',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VE',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/13PNOP7VKrtWwQk5EIwU4z'},
#      'href': 'https://api.spotify.com/v1/albums/13PNOP7VKrtWwQk5EIwU4z',
#      'id': '13PNOP7VKrtWwQk5EIwU4z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b3dda6c2e944579dba30d6ab',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b3dda6c2e944579dba30d6ab',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b3dda6c2e944579dba30d6ab',
#        'width': 64}],
#      'name': 'Troubadour',
#      'release_date': '2015-05-04',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:13PNOP7VKrtWwQk5EIwU4z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/27JrHY7vnpdv1zEfe3F8FQ'},
#       'href': 'https://api.spotify.com/v1/artists/27JrHY7vnpdv1zEfe3F8FQ',
#       'id': '27JrHY7vnpdv1zEfe3F8FQ',
#       'name': 'Beken',
#       'type': 'artist',
#       'uri': 'spotify:artist:27JrHY7vnpdv1zEfe3F8FQ'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'disc_number': 1,
#     'duration_ms': 215026,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USR5C1500401'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5igPALpL3Ljrg65UPrFPSw'},
#     'href': 'https://api.spotify.com/v1/tracks/5igPALpL3Ljrg65UPrFPSw',
#     'id': '5igPALpL3Ljrg65UPrFPSw',
#     'is_local': False,
#     'name': "Kote'w Te Ye",
#     'popularity': 30,
#     'preview_url': 'https://p.scdn.co/mp3-preview/442b4d1df810a2c6e6aa1d4c90e7f737a23888aa?cid=af3a4e21d9974f798b0ddef081728f2b',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5igPALpL3Ljrg65UPrFPSw'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-11-13T08:12:01Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7Lvyl6TYYWQAL0HkXlW9xp'},
#      'href': 'https://api.spotify.com/v1/albums/7Lvyl6TYYWQAL0HkXlW9xp',
#      'id': '7Lvyl6TYYWQAL0HkXlW9xp',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ee6bcccd936af5369a7838a1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ee6bcccd936af5369a7838a1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ee6bcccd936af5369a7838a1',
#        'width': 64}],
#      'name': 'Patsatsina Samotkhe',
#      'release_date': '2013-09-09',
#      'release_date_precision': 'day',
#      'total_tracks': 193,
#      'type': 'album',
#      'uri': 'spotify:album:7Lvyl6TYYWQAL0HkXlW9xp'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3VnWdQphcid07w4t1K8ncu'},
#       'href': 'https://api.spotify.com/v1/artists/3VnWdQphcid07w4t1K8ncu',
#       'id': '3VnWdQphcid07w4t1K8ncu',
#       'name': 'Stefane',
#       'type': 'artist',
#       'uri': 'spotify:artist:3VnWdQphcid07w4t1K8ncu'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 273800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'RUA1D1811248'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0eJKB81AQlfb0eug8b1c12'},
#     'href': 'https://api.spotify.com/v1/tracks/0eJKB81AQlfb0eug8b1c12',
#     'id': '0eJKB81AQlfb0eug8b1c12',
#     'is_local': False,
#     'name': 'Trialebs',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 111,
#     'type': 'track',
#     'uri': 'spotify:track:0eJKB81AQlfb0eug8b1c12'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2020-12-08T10:31:56Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/agnieu'},
#     'href': 'https://api.spotify.com/v1/users/agnieu',
#     'id': 'agnieu',
#     'type': 'user',
#     'uri': 'spotify:user:agnieu'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ls2WeFdaXVNgCq5zWKDjF'},
#        'href': 'https://api.spotify.com/v1/artists/7ls2WeFdaXVNgCq5zWKDjF',
#        'id': '7ls2WeFdaXVNgCq5zWKDjF',
#        'name': 'Le Parody',
#        'type': 'artist',
#        'uri': 'spotify:artist:7ls2WeFdaXVNgCq5zWKDjF'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/47i4lPow1dIRwOb85AB6lj'},
#        'href': 'https://api.spotify.com/v1/artists/47i4lPow1dIRwOb85AB6lj',
#        'id': '47i4lPow1dIRwOb85AB6lj',
#        'name': 'Gizmo Varillas',
#        'type': 'artist',
#        'uri': 'spotify:artist:47i4lPow1dIRwOb85AB6lj'}],
#      'available_markets': [],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0f09NyE7q6RZbHJe1GBIKA'},
#      'href': 'https://api.spotify.com/v1/albums/0f09NyE7q6RZbHJe1GBIKA',
#      'id': '0f09NyE7q6RZbHJe1GBIKA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273762cac73189f5708858cd83c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02762cac73189f5708858cd83c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851762cac73189f5708858cd83c',
#        'width': 64}],
#      'name': 'Summer Rain',
#      'release_date': '2015-07-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0f09NyE7q6RZbHJe1GBIKA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7ls2WeFdaXVNgCq5zWKDjF'},
#       'href': 'https://api.spotify.com/v1/artists/7ls2WeFdaXVNgCq5zWKDjF',
#       'id': '7ls2WeFdaXVNgCq5zWKDjF',
#       'name': 'Le Parody',
#       'type': 'artist',
#       'uri': 'spotify:artist:7ls2WeFdaXVNgCq5zWKDjF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/47i4lPow1dIRwOb85AB6lj'},
#       'href': 'https://api.spotify.com/v1/artists/47i4lPow1dIRwOb85AB6lj',
#       'id': '47i4lPow1dIRwOb85AB6lj',
#       'name': 'Gizmo Varillas',
#       'type': 'artist',
#       'uri': 'spotify:artist:47i4lPow1dIRwOb85AB6lj'}],
#     'available_markets': [],
#     'disc_number': 1,
#     'duration_ms': 190111,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKADC1500019'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/37srX95yEWagMPkspM1xr1'},
#     'href': 'https://api.spotify.com/v1/tracks/37srX95yEWagMPkspM1xr1',
#     'id': '37srX95yEWagMPkspM1xr1',
#     'is_local': False,
#     'name': 'Summer Rain',
#     'popularity': 0,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:37srX95yEWagMPkspM1xr1'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/4PuzKqMQjuIvn3Arkgaek2/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 116}

# %%
results = sp.user_playlist(user=None, playlist_id="4PuzKqMQjuIvn3Arkgaek2", fields="name")
results
# Out:
# {'name': 'WorldBeatz'}

# %%
def get_playlist_tracks(username, playlist_id):
    
    results = sp.user_playlist_tracks(username, playlist_id)
    tracks = results['items']
    
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    
    return tracks

tracks = get_playlist_tracks("spotify", "4PuzKqMQjuIvn3Arkgaek2")

# %%
playlist['total']
# Out:
# 116

# %% [markdown]
# #### Getting the artist anmes, track names and ids in one dictionary.

# %%
def get_ids_and_names_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    track_ids = []
    track_names = []
    
    for track in tracks_from_playlist:
        track_artists = track['track']['artists']
        track_id = track['track']['id']
        track_name = track['track']['name']
        
        for artist in track_artists:
            artist_name = artist['name']
            artists.append(artist_name)
        
        track_ids.append(track_id)
        track_names.append(track_name)
    
    return artists, track_ids, track_names

# %%
artists, track_ids, track_names = get_ids_and_names_from_playlist("4PuzKqMQjuIvn3Arkgaek2")
artists, track_ids, track_names
# Out:
# (['Farfashah',
#   'Stromae',
#   'Iain Mackenzie',
#   'Diamond Platnumz',
#   'The Soil',
#   'Mayra Andrade',
#   'Andro El Hawy',
#   'Hakuwaitim',
#   'Bei Bei',
#   'Los Macorinos',
#   'Dudu Tassa',
#   'Magic System',
#   'Pedrito Martinez',
#   'Camélia Jordana',
#   'Orchestra Baobab',
#   'Candan Erçetin',
#   'Ahmed Fakroun',
#   'The Notwist',
#   'Armand Amar',
#   'Rachel Chinouriri',
#   "l'Orchestre Afrisa International",
#   'Rex Lawson',
#   'Soapkills',
#   'Willy William',
#   'Tiken Jah Fakoly',
#   'Piero',
#   'Aziza Brahim',
#   'Systema Solar',
#   'KillBeatz',
#   'Yara',
#   'Benoit Cassar',
#   "L'Orchestre Massako",
#   'Daoud Al-Kuwaiti',
#   'Yolanda Eyama',
#   'Alvaro Soler',
#   'Natalia Lafourcade',
#   'Cibelle',
#   'Franco',
#   'TPOK Jazz',
#   'Gulili Mankoo',
#   'Amine Aub',
#   'Sun-El Musician',
#   'Da Capo',
#   'Kelman Duran',
#   'Los Gaiteros de San Jacinto',
#   'Hamza',
#   'Mi Casa',
#   'Oumou Sangaré',
#   'Bana',
#   'Bebe',
#   'Chiemi Eri',
#   'Elf Kid',
#   'Nancy Ajram',
#   'A.R. Rahman',
#   'Lila Downs',
#   'Hans Nieswandt',
#   'The Souljazz Orchestra',
#   'Jojo Effect',
#   'Nozinja',
#   'Masego',
#   'Clueso',
#   'Eartha Kitt',
#   'Amparanoia',
#   'Raury',
#   'Beken',
#   'Subculture',
#   'Letta Mbulu',
#   'De Frank Professionals',
#   'Songhoy Blues',
#   'Tll Groove',
#   'Miriam Makeba',
#   'Collins Oke Elaiho and His Odologie Nobles Dance Band',
#   'Boulpik',
#   'Gizmo Varillas',
#   'Stefane',
#   'Ragheb Alama',
#   'Michou',
#   'Los Vaqueros de San Luis',
#   'Bombino',
#   'Lijadu Sisters',
#   'Nazaré Peirera',
#   'Simmy',
#   'Ragheb',
#   'Habib Koité',
#   'Jubin Nautiyal',
#   'Amara Touré',
#   'Rif Cohen',
#   'Timekode',
#   'Francesco Wilking',
#   'Amr Diab',
#   'Orchestre Poly-Rythmo de Cotonou',
#   'Simge',
#   'Papa Wemba',
#   'Guitara',
#   'Bitori',
#   'Burak King',
#   'Malika Ayane',
#   'Dj Youcef',
#   'Tabu Ley Rochereau',
#   'Chambao',
#   'Tanishk Bagchi',
#   'Alsarah & The Nubatones',
#   'Nviiri The Storyteller',
#   'Shashaa Tirupati',
#   'Guts',
#   'Umm Kulthum',
#   'Nour Sooska',
#   'Wael Kfoury',
#   'Pinduca',
#   'Django Reinhardt',
#   'Blitz The Ambassador',
#   'Crucchi Gang',
#   'Jarabe De Palo',
#   'Nusrat Fateh Ali Khan',
#   'Shawn Lee',
#   'Nelson Freitas',
#   'Mugeez',
#   'Les Négresses Vertes',
#   'Chicago Afrobeat Project',
#   'Hugh Masekela',
#   'Banda Comunale',
#   'Fuse ODG',
#   'Manu Chao',
#   'Quintette du Hot Club de France',
#   'Badshah',
#   'Khaled',
#   'Fnaire',
#   'Can 7',
#   'Le Parody',
#   'Elissa',
#   'Nick Mulvey',
#   'Vicente Garcia',
#   'Sezen Aksu',
#   "K'NAAN",
#   'Berkay',
#   'Natacha Atlas',
#   'Ondatrópica',
#   'Daniel Haaksman',
#   'Samthing Soweto',
#   'Matt Johnson',
#   'Jul De Grenelle',
#   'Pongo',
#   'Fares Karam',
#   'Al Massrieen',
#   'Evi-Edna Ogholi',
#   'TootArd'],
#  ['2r3OCxXToV0DoXi0Cwf5LZ',
#   '7MmuoqMXkyUvzkUtR6pH5N',
#   '3ZLz817NgIAr4IxZxvd9hU',
#   '0LpNLPdGvZLATY6JgdbQzk',
#   '3UhMrPQkV70OWjhRPZnqi9',
#   '1qQqHzG5JAYD2bV1DGf5v7',
#   '3E2cxGYBulFh1JA4hkdont',
#   '6Xg94xsCFHtogZEin4ZoIk',
#   '0d6nZBImQyT3ypZQbyBPvu',
#   '12jBokt4TPkm3H3F6k8HSn',
#   '67OOgbV2tnbkMjWSgIrWMx',
#   '6fOCGlTiIPzx5YP2vYQMnZ',
#   '5ak2hgkL7iZKMxm7jGUHwC',
#   '5xlu3xpamok0JTgjMs5X1h',
#   '0ZI6SlESpFndsNHmRRZHmG',
#   '7uwpjUUxBPfFkjkZw12K43',
#   '382x0IaQk1Nqx2f3Xzfy14',
#   '0jQ4lqzx8tXioEdT0FRzZ7',
#   '4R5YG3XsReZ8zMq3p0rl70',
#   '1pD52RIAJeW8pd75WRBSSx',
#   '2eRBiykVYTrXdsbGUI0Dte',
#   '0WyiV16xWwytuHwbsBumYO',
#   '5NsiCv0naWyNsisixGy1LC',
#   '1SOi9UJSmT7px8yTGCIPD9',
#   '2X5th7ymavqAnYyvMAZtub',
#   '2j6qaYClA4UgQjfsSfV9O0',
#   '24bEKUUa0beebfNq0FHe5t',
#   '0FAcLiMKZoH4vLIXGQJgKF',
#   '0o4LONBlP5Z8iS3Pn5z232',
#   '0tbIPawbJhfi6gphH9zOEc',
#   '2E1LVeUE22erDMMqtK1pjP',
#   '6ePmQaBt9JdiVUGxPa7u4t',
#   '2Xbe1o0o2HlXPHK6qQjtZU',
#   '3D6tcOAAYJ689BNDjQHA4L',
#   '7lVI67idjeYODRkN8TkWKK',
#   '1sCS1W85fLPFYGhLvoIjK1',
#   '0JtZGBduXu64rLxGjWMsgR',
#   '5G1K67g9tGaKRZEXoSXwHq',
#   '6fU5IcE5XtFEmz87NIICI2',
#   '7wTpbnNsiqiSoEOMPfXPaN',
#   '2pannZXJ2mHOy6sxsQxjRa',
#   '5VFYAIGOvkulvCLlg5PTjG',
#   '4zI20oWjDbnkpaXny0J3b5',
#   '1vqv1rhGSeI9T68G18JYmk',
#   '1sK1Ph5u2Xsi1Z6oId3C5Q',
#   '5DsIDJq1BoCu7LlfYG8dwb',
#   '292VsF6mrqh2U1eS4qRN08',
#   '17TQwSwgFYl0kMtnZLbt5s',
#   '6bgBMK3FaL7hpuLiTAeplu',
#   '7AXTKNPFKqi8iyR95jB1HV',
#   '06nFWQALM6cTQAUEPx3ASx',
#   '6wdSIdZINhoXjynFa7s49k',
#   '2OaBQc07gJ9ZcDJJhhCMSf',
#   '3lLEnRDT33Nta9cjFRW0cR',
#   '4z1Gmmecbbn6Pw5ncFGEq7',
#   '0F1UDr3MEQg6CCyzAZW4Yf',
#   '6O7hhnacpxBjObl6DWdGLp',
#   '1vqv1rhGSeI9T68G18JYmk',
#   '4ewr2YZx2pXsxDTC4mWFob',
#   '79vn8aL5iSKxAfJL0rRHIw',
#   '5EaCh0zPofoiims8u2J57L',
#   '5n1eRVJN1giPeMOXiJejwh',
#   '0NJyThbEN5v6vFWrsH5uPF',
#   '5JBC6rYcOgVUW4nVWnbKYr',
#   '6DWIczhZwsUX8GJKrsL5IJ',
#   '2ELJPmLw6sozAdCOJruYbh',
#   '6NqZMhUaWX7dyLFdctJuW9',
#   '6zWU7YALeEDMcPGhKKZJhV',
#   '3SiNhRfBah30npNwyaoS22',
#   '3Hs7J4Gftz0WeDuZ97epkn',
#   '0C7dB2HDzhC4718PHBhHpz',
#   '1uJuHWY8WvUrxOiGWbenIl',
#   '1mYlDdkwaAZMv2pbijkVoS',
#   '3WjY4zxA37Mwtc6gSwzyYa',
#   '4otOKshv8wpDsMYfdV3BY6',
#   '1CZTjKkFUv1JSfF7LgwXW3',
#   '2SUd7akvmHCdbSEJJFAo9l',
#   '7gBggGrRJTxhNChZZprBqS',
#   '2Yo6rxooFyWBuoKKoNJWWe',
#   '6QR0uo8YrnH3MOlSG3jmbZ',
#   '2gvhbU2mvwxITWzCI0q9CS',
#   '2z6hguvjJemg3zmaLoZGNA',
#   '2MLxpHtqNLlUmXTkVXai6w',
#   '7BsVRE0B9LlDkCqALQMQad',
#   '7jZFd3Zv4h6uzyS2JJUvI9',
#   '1c3FHW0hC4HyJ1nkCXkWaw',
#   '6IwbrqhA8HxDwcIWNbAbGV',
#   '3jdIHTf8IjrvEP7DF8aOC1',
#   '2HmepoZPVcDPAaYlIOI4Ja',
#   '7Deb4scGmEv4fY2CZcVnSb',
#   '3bWMCH2M7JWUga1WRagDzs',
#   '50cT7mXkTHhKvt2HBV7lme',
#   '5H5yQqdVJSK9VW5fxMUI4M',
#   '6ry3OEfEOY8IYaCEcPFCsj',
#   '2KkeufbaO1ET6exci5rQle',
#   '4h3wVKjCwSefpn9XTDBgRV',
#   '6JYcFSZnlDWvbHvUcwP2XL',
#   '5igPALpL3Ljrg65UPrFPSw',
#   '0eJKB81AQlfb0eug8b1c12',
#   '37srX95yEWagMPkspM1xr1',
#   '7yIMFZSlcyZLls9Qx6nWL5',
#   '7k9Hjpkzrx0CQsJwRyDzip',
#   '3fX5B80DIcXFjSHQMHWJq7',
#   '6YPaq5MbxQDKxnODtg4CKy',
#   '0R7q8BHMfRYp38u8hQ1OwA',
#   '1189n1e3OsSBwpoqw5bd0T',
#   '3vXnuFnC5RhPGwsFi0ORcI',
#   '5omgFpiMt1CGHjQGfkwzvz',
#   '6lmZ6tVwc1LegWEfdyDuXv',
#   '7sxkCTOhTxfrZDh6UAI33E',
#   '0P2HFqXUhqvdZ2bS8doDjR',
#   '7heMX7gyHP0mhTlNgd7Lxd',
#   '5yOT1pfZeSCaJXYjPdWNIK',
#   '2ciDUdQR3JoUnjFJpdF9Cg',
#   '7qDYeY8zWoD7RsOLSk0cIy',
#   '0eQqBT6borm4PCvC7QncJq'],
#  ['Munana',
#   'Sey',
#   'Qusad Einy',
#   '1er Gaou',
#   'Ya Ghaly - Danai Remix',
#   'Nasini El Donya',
#   'قلب و روح',
#   'Beyt Habibi',
#   'Al Gharam El Moustahil',
#   'Amulet - 2005 Edit',
#   'Nisyan',
#   'Timtar',
#   'Sah',
#   'Halet Hob',
#   "Ebda' Men Gedid",
#   'Pontin Pontin',
#   'Tiene Sabor, Tiene Sazón',
#   'Ware Wa',
#   'Kossa Kossa (Tk Kossa Remix) [feat. Timekode]',
#   'Talking Bush',
#   'Zizi',
#   'Caribbean - Original Mix',
#   'Bere Bote',
#   'Obaro',
#   'Simini-Yaga',
#   "Life's Gone Down Low",
#   'Ego - Radio Edit',
#   'Wassiye',
#   'Mamá',
#   '3roos Elneel',
#   'Nha Baby',
#   'Mama Ndiyahamba',
#   'Kamelemba (Radio Edit)',
#   'Otemoyan',
#   'Ya Verás',
#   'Tela',
#   'Mali Nord',
#   'Akhaduhu Mini Urah',
#   'Alf Lela We Lela',
#   'Myela',
#   'Herzan',
#   'Year of the Funky',
#   'Espuma y Arrecife (feat. Los Gaiteros de San Jacinto)',
#   'Dakoro',
#   'Maloya ton tisane',
#   'Feel the Same',
#   'Celicia',
#   'Chacun pour soi',
#   'Al Chayeb',
#   'Aïcha',
#   'Bokor Bokor (feat. Fuse Odg & Mugeez)',
#   'Oublier pour un jour',
#   'Akanamali (feat. Samthing Soweto)',
#   "Sólo Vivo Pa' Quererte",
#   'Nèg Dafrik',
#   '1994',
#   'Marmagha',
#   'Dakoro',
#   'Grazing In The Grass',
#   'Mahlalela (Feat. Letta Mbulu)',
#   'Xihukwani',
#   'Uska Dara - Hans Nieswandt Mix',
#   'Inta Eyh',
#   'Mar estrecho (feat. Chambao)',
#   'Face à la mer',
#   'Sahra',
#   'Ahebek',
#   'Navajo',
#   'Koştum Hekime',
#   'Si No Te Tengo A Ti',
#   'Ele İnat',
#   'Minor Swing',
#   'On entre O.K on sort K.O',
#   'Al Ein Moona Yetain',
#   'Bamba',
#   'Ben Bazen',
#   'Bongo bong',
#   'Tehigren (The Trees )',
#   'Kuzola',
#   "Pa' Todo el Ano",
#   'Tú Sí Sabes Quererme',
#   'Diferentemente iguales',
#   'Manifesto',
#   'Fatima',
#   'Mambo Tonight',
#   'Accra City Blues',
#   'Afe Ato Yen Bio',
#   'Yolele',
#   'Click Song Number 1',
#   "Je ne t'aime plus",
#   'Mi Viejo',
#   'Yüksek Yüksek Tepelere',
#   "God's Whisper",
#   'Nosso Carimbó é do Mundo',
#   'Sedaye Baroon',
#   'Tiembla',
#   'Halet Hob & Ertah W Eish',
#   "Kote'w Te Ye",
#   'Trialebs',
#   'Summer Rain',
#   'La Tierra Derrama Lágrimas',
#   'Tere Bin Nahin Lagda - Original',
#   'Emakhaya (feat. Da Capo & Sun-El Musician)',
#   'Mae Wendi',
#   'The River Bend',
#   'Buscando la paz',
#   'Santé',
#   'Agua',
#   'Solo una parola',
#   'Corpo Sujeito - Kelman Duran Remix',
#   'Havana - Acoustic',
#   'The Humma Song',
#   'Exit Strategy To Myself',
#   'Femmes',
#   'Ballare',
#   'Poêm of the Atoms II'])

# %% [markdown]
# #### Let's check the length of each list. There might be more artists since some songs are associated with more than one artist registered on Spotify.

# %%
print("Number of artists:", len(artists))  
print("Number of track IDs:", len(track_ids)) 
print("Number of track names:", len(track_names))
# Out:
# Number of artists: 146
# Number of track IDs: 116
# Number of track names: 116

# %% [markdown]
# #### I want to have the column `artists` in my final dataframe, hence I need to add the second artist in its own row.

# %%
def get_ids_and_names_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    
    artists = []
    track_ids = []
    track_names = []
    
    for track in tracks_from_playlist:
        track_artists = track['track']['artists']
        track_id = track['track']['id']
        track_name = track['track']['name']
        
        for artist in track_artists:
            artist_name = artist['name']
            artists.append(artist_name)
            track_ids.append(track_id)
            track_names.append(track_name)
    
    return artists, track_ids, track_names

artists, track_ids, track_names = get_ids_and_names_from_playlist("4PuzKqMQjuIvn3Arkgaek2")

# %%
df1 = pd.DataFrame({'Artist': artists, 'Song': track_names, 'Song ID': track_ids})
df1
# Out:
#                Artist                     Song                 Song ID
# 0              Bitori                   Munana  2r3OCxXToV0DoXi0Cwf5LZ
# 1    Orchestra Baobab                      Sey  7MmuoqMXkyUvzkUtR6pH5N
# 2            Amr Diab               Qusad Einy  3ZLz817NgIAr4IxZxvd9hU
# 3        Magic System                 1er Gaou  0LpNLPdGvZLATY6JgdbQzk
# 4     Jul De Grenelle   Ya Ghaly - Danai Remix  3UhMrPQkV70OWjhRPZnqi9
# ..                ...                      ...                     ...
# 155       The Notwist  Exit Strategy To Myself  5yOT1pfZeSCaJXYjPdWNIK
# 156   Camélia Jordana                   Femmes  2ciDUdQR3JoUnjFJpdF9Cg
# 157      Crucchi Gang                  Ballare  7qDYeY8zWoD7RsOLSk0cIy
# 158            Clueso                  Ballare  7qDYeY8zWoD7RsOLSk0cIy
# 159       Armand Amar     Poêm of the Atoms II  0eQqBT6borm4PCvC7QncJq
#
# [160 rows x 3 columns]

# %% [markdown]
# #### In order to get the audio fetaures of more than 100 tracks I am splitting into batches, then append. (Help of ChatGPT)

# %%
track_ids = track_ids[:160]

# Split track IDs into batches of 100
batch_size = 100
num_batches = math.ceil(len(track_ids) / batch_size)
audio_features = []

for i in range(num_batches):
    start = i * batch_size
    end = (i + 1) * batch_size
    batch_track_ids = track_ids[start:end]
    
# Request audio features for the current batch of track IDs
    batch_audio_features = sp.audio_features(batch_track_ids)
    audio_features.extend(batch_audio_features)

# %%
df2 = pd.json_normalize(audio_features)
df2
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.867  0.6870    6    -9.804     1       0.0942        0.0306
# 1           0.595  0.6670    8    -5.007     0       0.0305        0.3730
# 2           0.657  0.4920    0    -9.375     0       0.0382        0.4250
# 3           0.850  0.9250    7    -4.209     0       0.0862        0.1500
# 4           0.780  0.6080    7   -11.356     0       0.0533        0.5550
# ..            ...     ...  ...       ...   ...          ...           ...
# 155         0.349  0.8920    2    -1.919     1       0.0435        0.0146
# 156         0.771  0.5850    4    -6.498     0       0.0571        0.1110
# 157         0.766  0.6540    9    -7.861     0       0.0619        0.5320
# 158         0.766  0.6540    9    -7.861     0       0.0619        0.5320
# 159         0.163  0.0811   11   -16.510     0       0.0350        0.8750
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.040900    0.1130    0.847   88.614  audio_features
# 1            0.003050    0.2020    0.938   97.790  audio_features
# 2            0.000018    0.3650    0.409   77.887  audio_features
# 3            0.000000    0.0600    0.882  119.042  audio_features
# 4            0.200000    0.1060    0.664  129.964  audio_features
# ..                ...       ...      ...      ...             ...
# 155          0.828000    0.0743    0.319  164.932  audio_features
# 156          0.012200    0.1590    0.464   97.065  audio_features
# 157          0.000042    0.1170    0.836   99.982  audio_features
# 158          0.000042    0.1170    0.836   99.982  audio_features
# 159          0.022000    0.0960    0.104   86.212  audio_features
#
#                          id                                   uri  \
# 0    2r3OCxXToV0DoXi0Cwf5LZ  spotify:track:2r3OCxXToV0DoXi0Cwf5LZ
# 1    7MmuoqMXkyUvzkUtR6pH5N  spotify:track:7MmuoqMXkyUvzkUtR6pH5N
# 2    3ZLz817NgIAr4IxZxvd9hU  spotify:track:3ZLz817NgIAr4IxZxvd9hU
# 3    0LpNLPdGvZLATY6JgdbQzk  spotify:track:0LpNLPdGvZLATY6JgdbQzk
# 4    3UhMrPQkV70OWjhRPZnqi9  spotify:track:3UhMrPQkV70OWjhRPZnqi9
# ..                      ...                                   ...
# 155  5yOT1pfZeSCaJXYjPdWNIK  spotify:track:5yOT1pfZeSCaJXYjPdWNIK
# 156  2ciDUdQR3JoUnjFJpdF9Cg  spotify:track:2ciDUdQR3JoUnjFJpdF9Cg
# 157  7qDYeY8zWoD7RsOLSk0cIy  spotify:track:7qDYeY8zWoD7RsOLSk0cIy
# 158  7qDYeY8zWoD7RsOLSk0cIy  spotify:track:7qDYeY8zWoD7RsOLSk0cIy
# 159  0eQqBT6borm4PCvC7QncJq  spotify:track:0eQqBT6borm4PCvC7QncJq
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/2r3OCxXToV0D...
# 1    https://api.spotify.com/v1/tracks/7MmuoqMXkyUv...
# 2    https://api.spotify.com/v1/tracks/3ZLz817NgIAr...
# 3    https://api.spotify.com/v1/tracks/0LpNLPdGvZLA...
# 4    https://api.spotify.com/v1/tracks/3UhMrPQkV70O...
# ..                                                 ...
# 155  https://api.spotify.com/v1/tracks/5yOT1pfZeSCa...
# 156  https://api.spotify.com/v1/tracks/2ciDUdQR3JoU...
# 157  https://api.spotify.com/v1/tracks/7qDYeY8zWoD7...
# 158  https://api.spotify.com/v1/tracks/7qDYeY8zWoD7...
# 159  https://api.spotify.com/v1/tracks/0eQqBT6borm4...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2r3O...       258777
# 1    https://api.spotify.com/v1/audio-analysis/7Mmu...       274840
# 2    https://api.spotify.com/v1/audio-analysis/3ZLz...       264255
# 3    https://api.spotify.com/v1/audio-analysis/0LpN...       294200
# 4    https://api.spotify.com/v1/audio-analysis/3UhM...       223304
# ..                                                 ...          ...
# 155  https://api.spotify.com/v1/audio-analysis/5yOT...       188667
# 156  https://api.spotify.com/v1/audio-analysis/2ciD...       161880
# 157  https://api.spotify.com/v1/audio-analysis/7qDY...       208601
# 158  https://api.spotify.com/v1/audio-analysis/7qDY...       208601
# 159  https://api.spotify.com/v1/audio-analysis/0eQq...       139747
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 155               4
# 156               4
# 157               4
# 158               4
# 159               1
#
# [160 rows x 18 columns]

# %%
df2 = df2.rename(columns=lambda x: x.capitalize())
df2 = df2.rename(columns={'Id': 'Song ID'})

# %%
songs_and_features = pd.merge(df1, df2, on="Song ID", how="outer")
songs_and_features
# Out:
#                Artist                    Song                 Song ID  \
# 0              Bitori                  Munana  2r3OCxXToV0DoXi0Cwf5LZ
# 1    Orchestra Baobab                     Sey  7MmuoqMXkyUvzkUtR6pH5N
# 2            Amr Diab              Qusad Einy  3ZLz817NgIAr4IxZxvd9hU
# 3        Magic System                1er Gaou  0LpNLPdGvZLATY6JgdbQzk
# 4     Jul De Grenelle  Ya Ghaly - Danai Remix  3UhMrPQkV70OWjhRPZnqi9
# ..                ...                     ...                     ...
# 279      Crucchi Gang                 Ballare  7qDYeY8zWoD7RsOLSk0cIy
# 280      Crucchi Gang                 Ballare  7qDYeY8zWoD7RsOLSk0cIy
# 281            Clueso                 Ballare  7qDYeY8zWoD7RsOLSk0cIy
# 282            Clueso                 Ballare  7qDYeY8zWoD7RsOLSk0cIy
# 283       Armand Amar    Poêm of the Atoms II  0eQqBT6borm4PCvC7QncJq
#
#      Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 0           0.867  0.6870    6    -9.804     1       0.0942        0.0306
# 1           0.595  0.6670    8    -5.007     0       0.0305        0.3730
# 2           0.657  0.4920    0    -9.375     0       0.0382        0.4250
# 3           0.850  0.9250    7    -4.209     0       0.0862        0.1500
# 4           0.780  0.6080    7   -11.356     0       0.0533        0.5550
# ..            ...     ...  ...       ...   ...          ...           ...
# 279         0.766  0.6540    9    -7.861     0       0.0619        0.5320
# 280         0.766  0.6540    9    -7.861     0       0.0619        0.5320
# 281         0.766  0.6540    9    -7.861     0       0.0619        0.5320
# 282         0.766  0.6540    9    -7.861     0       0.0619        0.5320
# 283         0.163  0.0811   11   -16.510     0       0.0350        0.8750
#
#      Instrumentalness  Liveness  Valence    Tempo            Type  \
# 0            0.040900     0.113    0.847   88.614  audio_features
# 1            0.003050     0.202    0.938   97.790  audio_features
# 2            0.000018     0.365    0.409   77.887  audio_features
# 3            0.000000     0.060    0.882  119.042  audio_features
# 4            0.200000     0.106    0.664  129.964  audio_features
# ..                ...       ...      ...      ...             ...
# 279          0.000042     0.117    0.836   99.982  audio_features
# 280          0.000042     0.117    0.836   99.982  audio_features
# 281          0.000042     0.117    0.836   99.982  audio_features
# 282          0.000042     0.117    0.836   99.982  audio_features
# 283          0.022000     0.096    0.104   86.212  audio_features
#
#                                       Uri  \
# 0    spotify:track:2r3OCxXToV0DoXi0Cwf5LZ
# 1    spotify:track:7MmuoqMXkyUvzkUtR6pH5N
# 2    spotify:track:3ZLz817NgIAr4IxZxvd9hU
# 3    spotify:track:0LpNLPdGvZLATY6JgdbQzk
# 4    spotify:track:3UhMrPQkV70OWjhRPZnqi9
# ..                                    ...
# 279  spotify:track:7qDYeY8zWoD7RsOLSk0cIy
# 280  spotify:track:7qDYeY8zWoD7RsOLSk0cIy
# 281  spotify:track:7qDYeY8zWoD7RsOLSk0cIy
# 282  spotify:track:7qDYeY8zWoD7RsOLSk0cIy
# 283  spotify:track:0eQqBT6borm4PCvC7QncJq
#
#                                             Track_href  \
# 0    https://api.spotify.com/v1/tracks/2r3OCxXToV0D...
# 1    https://api.spotify.com/v1/tracks/7MmuoqMXkyUv...
# 2    https://api.spotify.com/v1/tracks/3ZLz817NgIAr...
# 3    https://api.spotify.com/v1/tracks/0LpNLPdGvZLA...
# 4    https://api.spotify.com/v1/tracks/3UhMrPQkV70O...
# ..                                                 ...
# 279  https://api.spotify.com/v1/tracks/7qDYeY8zWoD7...
# 280  https://api.spotify.com/v1/tracks/7qDYeY8zWoD7...
# 281  https://api.spotify.com/v1/tracks/7qDYeY8zWoD7...
# 282  https://api.spotify.com/v1/tracks/7qDYeY8zWoD7...
# 283  https://api.spotify.com/v1/tracks/0eQqBT6borm4...
#
#                                           Analysis_url  Duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2r3O...       258777
# 1    https://api.spotify.com/v1/audio-analysis/7Mmu...       274840
# 2    https://api.spotify.com/v1/audio-analysis/3ZLz...       264255
# 3    https://api.spotify.com/v1/audio-analysis/0LpN...       294200
# 4    https://api.spotify.com/v1/audio-analysis/3UhM...       223304
# ..                                                 ...          ...
# 279  https://api.spotify.com/v1/audio-analysis/7qDY...       208601
# 280  https://api.spotify.com/v1/audio-analysis/7qDY...       208601
# 281  https://api.spotify.com/v1/audio-analysis/7qDY...       208601
# 282  https://api.spotify.com/v1/audio-analysis/7qDY...       208601
# 283  https://api.spotify.com/v1/audio-analysis/0eQq...       139747
#
#      Time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 279               4
# 280               4
# 281               4
# 282               4
# 283               1
#
# [284 rows x 20 columns]

# %% [markdown]
# #### There are many duplicates now, logically. I want every song only once, I don't care by which of the cooperating artists since the audio features are related to the song not the artist, hence I drop duplicates of `Song ID`.

# %%
songs_and_features = songs_and_features.drop_duplicates(subset="Song ID")
songs_and_features
# Out:
#                Artist                     Song                 Song ID  \
# 0              Bitori                   Munana  2r3OCxXToV0DoXi0Cwf5LZ
# 1    Orchestra Baobab                      Sey  7MmuoqMXkyUvzkUtR6pH5N
# 2            Amr Diab               Qusad Einy  3ZLz817NgIAr4IxZxvd9hU
# 3        Magic System                 1er Gaou  0LpNLPdGvZLATY6JgdbQzk
# 4     Jul De Grenelle   Ya Ghaly - Danai Remix  3UhMrPQkV70OWjhRPZnqi9
# ..                ...                      ...                     ...
# 252       A.R. Rahman           The Humma Song  7heMX7gyHP0mhTlNgd7Lxd
# 277       The Notwist  Exit Strategy To Myself  5yOT1pfZeSCaJXYjPdWNIK
# 278   Camélia Jordana                   Femmes  2ciDUdQR3JoUnjFJpdF9Cg
# 279      Crucchi Gang                  Ballare  7qDYeY8zWoD7RsOLSk0cIy
# 283       Armand Amar     Poêm of the Atoms II  0eQqBT6borm4PCvC7QncJq
#
#      Danceability  Energy  Key  Loudness  Mode  Speechiness  Acousticness  \
# 0           0.867  0.6870    6    -9.804     1       0.0942        0.0306
# 1           0.595  0.6670    8    -5.007     0       0.0305        0.3730
# 2           0.657  0.4920    0    -9.375     0       0.0382        0.4250
# 3           0.850  0.9250    7    -4.209     0       0.0862        0.1500
# 4           0.780  0.6080    7   -11.356     0       0.0533        0.5550
# ..            ...     ...  ...       ...   ...          ...           ...
# 252         0.721  0.6500    0    -6.950     0       0.1350        0.0115
# 277         0.349  0.8920    2    -1.919     1       0.0435        0.0146
# 278         0.771  0.5850    4    -6.498     0       0.0571        0.1110
# 279         0.766  0.6540    9    -7.861     0       0.0619        0.5320
# 283         0.163  0.0811   11   -16.510     0       0.0350        0.8750
#
#      Instrumentalness  Liveness  Valence    Tempo            Type  \
# 0            0.040900    0.1130    0.847   88.614  audio_features
# 1            0.003050    0.2020    0.938   97.790  audio_features
# 2            0.000018    0.3650    0.409   77.887  audio_features
# 3            0.000000    0.0600    0.882  119.042  audio_features
# 4            0.200000    0.1060    0.664  129.964  audio_features
# ..                ...       ...      ...      ...             ...
# 252          0.000140    0.3400    0.392  130.487  audio_features
# 277          0.828000    0.0743    0.319  164.932  audio_features
# 278          0.012200    0.1590    0.464   97.065  audio_features
# 279          0.000042    0.1170    0.836   99.982  audio_features
# 283          0.022000    0.0960    0.104   86.212  audio_features
#
#                                       Uri  \
# 0    spotify:track:2r3OCxXToV0DoXi0Cwf5LZ
# 1    spotify:track:7MmuoqMXkyUvzkUtR6pH5N
# 2    spotify:track:3ZLz817NgIAr4IxZxvd9hU
# 3    spotify:track:0LpNLPdGvZLATY6JgdbQzk
# 4    spotify:track:3UhMrPQkV70OWjhRPZnqi9
# ..                                    ...
# 252  spotify:track:7heMX7gyHP0mhTlNgd7Lxd
# 277  spotify:track:5yOT1pfZeSCaJXYjPdWNIK
# 278  spotify:track:2ciDUdQR3JoUnjFJpdF9Cg
# 279  spotify:track:7qDYeY8zWoD7RsOLSk0cIy
# 283  spotify:track:0eQqBT6borm4PCvC7QncJq
#
#                                             Track_href  \
# 0    https://api.spotify.com/v1/tracks/2r3OCxXToV0D...
# 1    https://api.spotify.com/v1/tracks/7MmuoqMXkyUv...
# 2    https://api.spotify.com/v1/tracks/3ZLz817NgIAr...
# 3    https://api.spotify.com/v1/tracks/0LpNLPdGvZLA...
# 4    https://api.spotify.com/v1/tracks/3UhMrPQkV70O...
# ..                                                 ...
# 252  https://api.spotify.com/v1/tracks/7heMX7gyHP0m...
# 277  https://api.spotify.com/v1/tracks/5yOT1pfZeSCa...
# 278  https://api.spotify.com/v1/tracks/2ciDUdQR3JoU...
# 279  https://api.spotify.com/v1/tracks/7qDYeY8zWoD7...
# 283  https://api.spotify.com/v1/tracks/0eQqBT6borm4...
#
#                                           Analysis_url  Duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/2r3O...       258777
# 1    https://api.spotify.com/v1/audio-analysis/7Mmu...       274840
# 2    https://api.spotify.com/v1/audio-analysis/3ZLz...       264255
# 3    https://api.spotify.com/v1/audio-analysis/0LpN...       294200
# 4    https://api.spotify.com/v1/audio-analysis/3UhM...       223304
# ..                                                 ...          ...
# 252  https://api.spotify.com/v1/audio-analysis/7heM...       179658
# 277  https://api.spotify.com/v1/audio-analysis/5yOT...       188667
# 278  https://api.spotify.com/v1/audio-analysis/2ciD...       161880
# 279  https://api.spotify.com/v1/audio-analysis/7qDY...       208601
# 283  https://api.spotify.com/v1/audio-analysis/0eQq...       139747
#
#      Time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 252               5
# 277               4
# 278               4
# 279               4
# 283               1
#
# [115 rows x 20 columns]
